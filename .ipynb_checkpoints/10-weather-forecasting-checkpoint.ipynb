# %% [markdown]
# ##  Weather Forecasting
# ## Timeseries - LSTM model
# ### Gamze Keçibaş
# ---
# ### CONTENT
# - **Step 01.** Import libraries
# - **Step 02.** Import data
# - **Step 03.** Data visualization
# - **Step 04.** Check feature correlation
# - **Step 05.** Data preprocessing
# - **Step 06.** Training and Validation datasets
# - **Step 07.** Model training
# - **Step 08.** Plotting
# - **Step 09.** Predictions
# ---
# ### [resource](https://keras.io/examples/timeseries/timeseries_weather_forecasting/)

# %% [markdown]
# ### Step 01. Import libraries

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### Step 02. Import data
# - jena_climate_2009_2016 dataset is used.

# %%
data_dir= r'C:\Users\gkeciba1\Desktop'
fname= os.path.join(data_dir, 'jena_climate_2009_2016.xls')
f=open(fname)
data= f.read()
f.close()

lines= data.split('\n')
header= lines[0].split(',')
lines= lines[1:]
df = pd.read_csv(fname)

print(header)
print(len(lines))
# Out:
# ['"Date Time"', '"p (mbar)"', '"T (degC)"', '"Tpot (K)"', '"Tdew (degC)"', '"rh (%)"', '"VPmax (mbar)"', '"VPact (mbar)"', '"VPdef (mbar)"', '"sh (g/kg)"', '"H2OC (mmol/mol)"', '"rho (g/m**3)"', '"wv (m/s)"', '"max. wv (m/s)"', '"wd (deg)"']
# 420551

# %% [markdown]
# ### Step 03. Data visualization
# - Define titles, feature keys and plot

# %%
titles = [
    "Pressure",
    "Temperature",
    "Temperature in Kelvin",
    "Temperature (dew point)",
    "Relative Humidity",
    "Saturation vapor pressure",
    "Vapor pressure",
    "Vapor pressure deficit",
    "Specific humidity",
    "Water vapor concentration",
    "Airtight",
    "Wind speed",
    "Maximum wind speed",
    "Wind direction in degrees",
]

feature_keys = [
    "p (mbar)",
    "T (degC)",
    "Tpot (K)",
    "Tdew (degC)",
    "rh (%)",
    "VPmax (mbar)",
    "VPact (mbar)",
    "VPdef (mbar)",
    "sh (g/kg)",
    "H2OC (mmol/mol)",
    "rho (g/m**3)",
    "wv (m/s)",
    "max. wv (m/s)",
    "wd (deg)",
]

colors = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "olive",
    "cyan",
]

date_time_key = "Date Time"


time_data = df[date_time_key]
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k")
for i in range(len(feature_keys)):
    key = feature_keys[i]
    c = colors[i % (len(colors))]
    t_data = df[key]
    t_data.index = time_data
    t_data.head()
    ax = t_data.plot(
    ax=axes[i // 2, i % 2],
    color=c,
    title="{} - {}".format(titles[i], key), rot=25,)
    ax.legend([titles[i]])
    plt.tight_layout()

# %% [markdown]
# ### Step 04. Check feature correlation

# %%
plt.matshow(df.corr())
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90)
plt.gca().xaxis.tick_bottom()
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)

cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title("Feature Correlation Heatmap", fontsize=14)
plt.show()

# %% [markdown]
# ### Step 05. Data preprocessing

# %%
split_fraction = 0.8
train_split = int(split_fraction * int(df.shape[0]))
step = 6

past = 720
future = 72
learning_rate = 0.001
batch_size = 128
epochs = 10


def normalize(data, train_split):
    data_mean = data[:train_split].mean(axis=0)
    data_std = data[:train_split].std(axis=0)
    return (data - data_mean) / data_std

print(
    "The selected parameters are:",
    ", ".join([titles[i] for i in [0, 1, 5, 7, 8, 10, 11]]),
)
selected_features = [feature_keys[i] for i in [0, 1, 5, 7, 8, 10, 11]]
features = df[selected_features]
features.index = df[date_time_key]
features.head()

features = normalize(features.values, train_split)
features = pd.DataFrame(features)
features.head()

train_data = features.loc[0 : train_split - 1]
val_data = features.loc[train_split:]
# Out:
# The selected parameters are: Pressure, Temperature, Saturation vapor pressure, Vapor pressure deficit, Specific humidity, Airtight, Wind speed

# %% [markdown]
# ### Step 06. Training and Validation datasets

# %%
# Define training dataset
start = past + future
end = start + train_split

x_train = train_data[[i for i in range(7)]].values
y_train = features.iloc[start:end][[1]]

sequence_length = int(past / step)

dataset_train = keras.preprocessing.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

# Define validation dataset
x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][[i for i in range(7)]].values
y_val = features.iloc[label_start:][[1]]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)


for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)
# Out:
# Input shape: (128, 120, 7)
# Target shape: (128, 1)

# %% [markdown]
# ### Step 07. Model training

# %%
inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(14)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 120, 7)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 14)                1232
# _________________________________________________________________
# dense (Dense)                (None, 1)                 15
# =================================================================
# Total params: 1,247
# Trainable params: 1,247
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_checkpoint = "model_checkpoint.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# Epoch 1/10
# 2623/2623 [==============================] - 105s 40ms/step - loss: 0.1192 - val_loss: 0.1676
#
# Epoch 00001: val_loss improved from inf to 0.16758, saving model to model_checkpoint.h5
# Epoch 2/10
# 2623/2623 [==============================] - 97s 37ms/step - loss: 0.1172 - val_loss: 0.1626
#
# Epoch 00002: val_loss improved from 0.16758 to 0.16263, saving model to model_checkpoint.h5
# Epoch 3/10
# 2623/2623 [==============================] - 98s 38ms/step - loss: 0.1130 - val_loss: 0.1604
#
# Epoch 00003: val_loss improved from 0.16263 to 0.16039, saving model to model_checkpoint.h5
# Epoch 4/10
# 2623/2623 [==============================] - 100s 38ms/step - loss: 0.1110 - val_loss: 0.1550
#
# Epoch 00004: val_loss improved from 0.16039 to 0.15498, saving model to model_checkpoint.h5
# Epoch 5/10
# 2623/2623 [==============================] - 96s 37ms/step - loss: 0.1095 - val_loss: 0.1509
#
# Epoch 00005: val_loss improved from 0.15498 to 0.15087, saving model to model_checkpoint.h5
# Epoch 6/10
# 2623/2623 [==============================] - 93s 35ms/step - loss: 0.1079 - val_loss: 0.1493
#
# Epoch 00006: val_loss improved from 0.15087 to 0.14925, saving model to model_checkpoint.h5
# Epoch 7/10
# 2623/2623 [==============================] - 96s 37ms/step - loss: 0.1064 - val_loss: 0.1481
#
# Epoch 00007: val_loss improved from 0.14925 to 0.14808, saving model to model_checkpoint.h5
# Epoch 8/10
# 2623/2623 [==============================] - 91s 35ms/step - loss: 0.1051 - val_loss: 0.1490
#
# Epoch 00008: val_loss did not improve from 0.14808
# Epoch 9/10
# 2623/2623 [==============================] - 93s 35ms/step - loss: 0.1042 - val_loss: 0.1454
#
# Epoch 00009: val_loss improved from 0.14808 to 0.14538, saving model to model_checkpoint.h5
# Epoch 10/10
# 2623/2623 [==============================] - 94s 36ms/step - loss: 0.1034 - val_loss: 0.1438
#
# Epoch 00010: val_loss improved from 0.14538 to 0.14380, saving model to model_checkpoint.h5

# %%
# GRU- based model

model_gru = keras.models.Sequential()
model_gru.add(keras.layers.GRU(14, input_shape=(None, inputs.shape[-1])))
model_gru.add(keras.layers.Dense(1))

model_gru.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model_gru.summary()

path_checkpoint_gru = "model_checkpoint_gru.h5"
es_callback_gru = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback_gru = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history_gru = model_gru.fit(dataset_train, 
                            epochs=10, 
                            validation_data=dataset_val,
                            callbacks=[es_callback_gru, modelckpt_callback_gru],)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_5 (GRU)                  (None, 14)                966
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 981
# Trainable params: 981
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2623/2623 [==============================] - 277s 105ms/step - loss: 0.3035 - val_loss: 0.2158
#
# Epoch 00001: val_loss improved from inf to 0.21575, saving model to model_checkpoint.h5
# Epoch 2/10
# 2623/2623 [==============================] - 131s 50ms/step - loss: 0.1451 - val_loss: 0.1811
#
# Epoch 00002: val_loss improved from 0.21575 to 0.18106, saving model to model_checkpoint.h5
# Epoch 3/10
# 2623/2623 [==============================] - 124s 47ms/step - loss: 0.1219 - val_loss: 0.1800
#
# Epoch 00003: val_loss improved from 0.18106 to 0.17996, saving model to model_checkpoint.h5
# Epoch 4/10
# 2623/2623 [==============================] - 109s 42ms/step - loss: 0.1147 - val_loss: 0.1723
#
# Epoch 00004: val_loss improved from 0.17996 to 0.17231, saving model to model_checkpoint.h5
# Epoch 5/10
# 2623/2623 [==============================] - 107s 41ms/step - loss: 0.1112 - val_loss: 0.1650
#
# Epoch 00005: val_loss improved from 0.17231 to 0.16504, saving model to model_checkpoint.h5
# Epoch 6/10
# 2623/2623 [==============================] - 103s 39ms/step - loss: 0.1089 - val_loss: 0.1600
#
# Epoch 00006: val_loss improved from 0.16504 to 0.15998, saving model to model_checkpoint.h5
# Epoch 7/10
# 2623/2623 [==============================] - 108s 41ms/step - loss: 0.1074 - val_loss: 0.1558
#
# Epoch 00007: val_loss improved from 0.15998 to 0.15577, saving model to model_checkpoint.h5
# Epoch 8/10
# 2623/2623 [==============================] - 101s 39ms/step - loss: 0.1063 - val_loss: 0.1529
#
# Epoch 00008: val_loss improved from 0.15577 to 0.15294, saving model to model_checkpoint.h5
# Epoch 9/10
# 2623/2623 [==============================] - 100s 38ms/step - loss: 0.1052 - val_loss: 0.1506
#
# Epoch 00009: val_loss improved from 0.15294 to 0.15058, saving model to model_checkpoint.h5
# Epoch 10/10
# 2623/2623 [==============================] - 105s 40ms/step - loss: 0.1043 - val_loss: 0.1486
#
# Epoch 00010: val_loss improved from 0.15058 to 0.14862, saving model to model_checkpoint.h5

# %%
# GRU- based model with dropout- regularized

model_gru_drop = keras.models.Sequential()
model_gru_drop.add(keras.layers.GRU(14, dropout= 0.2, recurrent_dropout= 0.2, input_shape=(None, inputs.shape[-1])))
model_gru_drop.add(keras.layers.Dense(1))

model_gru_drop.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model_gru_drop.summary()

path_checkpoint_gru_drop = "model_checkpoint_gru_drop.h5"
es_callback_gru_drop = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback_gru_drop = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history_gru_drop = model_gru_drop.fit(dataset_train, 
                            epochs=10, 
                            validation_data=dataset_val,
                            callbacks=[es_callback_gru_drop, modelckpt_callback_gru_drop],)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_6 (GRU)                  (None, 14)                966
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 981
# Trainable params: 981
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2623/2623 [==============================] - 164s 62ms/step - loss: 0.2159 - val_loss: 0.2041
#
# Epoch 00001: val_loss improved from inf to 0.20409, saving model to model_checkpoint.h5
# Epoch 2/10
# 2623/2623 [==============================] - 161s 61ms/step - loss: 0.1589 - val_loss: 0.1583
#
# Epoch 00002: val_loss improved from 0.20409 to 0.15831, saving model to model_checkpoint.h5
# Epoch 3/10
# 2623/2623 [==============================] - 158s 60ms/step - loss: 0.1424 - val_loss: 0.1555
#
# Epoch 00003: val_loss improved from 0.15831 to 0.15546, saving model to model_checkpoint.h5
# Epoch 4/10
# 2623/2623 [==============================] - 169s 65ms/step - loss: 0.1351 - val_loss: 0.1512
#
# Epoch 00004: val_loss improved from 0.15546 to 0.15121, saving model to model_checkpoint.h5
# Epoch 5/10
# 2623/2623 [==============================] - 169s 64ms/step - loss: 0.1309 - val_loss: 0.1480
#
# Epoch 00005: val_loss improved from 0.15121 to 0.14796, saving model to model_checkpoint.h5
# Epoch 6/10
# 2623/2623 [==============================] - 173s 66ms/step - loss: 0.1279 - val_loss: 0.1453
#
# Epoch 00006: val_loss improved from 0.14796 to 0.14529, saving model to model_checkpoint.h5
# Epoch 7/10
# 2623/2623 [==============================] - 170s 65ms/step - loss: 0.1261 - val_loss: 0.1446
#
# Epoch 00007: val_loss improved from 0.14529 to 0.14463, saving model to model_checkpoint.h5
# Epoch 8/10
# 2623/2623 [==============================] - 233s 89ms/step - loss: 0.1242 - val_loss: 0.1441
#
# Epoch 00008: val_loss improved from 0.14463 to 0.14406, saving model to model_checkpoint.h5
# Epoch 9/10
# 2623/2623 [==============================] - 213s 81ms/step - loss: 0.1232 - val_loss: 0.1427
#
# Epoch 00009: val_loss improved from 0.14406 to 0.14266, saving model to model_checkpoint.h5
# Epoch 10/10
# 2623/2623 [==============================] - 210s 80ms/step - loss: 0.1222 - val_loss: 0.1416
#
# Epoch 00010: val_loss improved from 0.14266 to 0.14162, saving model to model_checkpoint.h5

# %% [markdown]
# ### Step 08. Plotting

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(len(loss))

loss_gru = history_gru.history["loss"]
val_loss_gru = history_gru.history["val_loss"]
epochs = range(len(loss_gru))

loss_gru_drop = history_gru_drop.history["loss"]
val_loss_gru_drop = history_gru_drop.history["val_loss"]
epochs = range(len(loss_gru_drop))


# PLOTTING
plt.figure()
plt.plot(epochs, loss, "b", label="Training loss")
plt.plot(epochs, val_loss, "r", label="Validation loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure()
fig, axs= plt.subplots(2,2, sharex= True, sharey= False)
axs[0,0].plot(epochs, loss_gru, "b", label="Training loss")
axs[1,0].plot(epochs, val_loss_gru, "r", label="Validation loss")
axs[0,1].plot(epochs, loss_gru_drop, "b", label="Training loss")
axs[1,1].plot(epochs, val_loss_gru_drop, "r", label="Validation loss")

plt.figtext(.300,1, "GRU-based Model\n", ha="center", va="top", fontsize=10)
plt.figtext(.750,1, "GRU-based | Dropout = 0.2 Model\n", ha="center", va="top", fontsize=10)
fig.text(0.300, 0.04, 'Epochs', ha='center', va='center')
fig.text(0.750, 0.04, 'Epochs', ha='center', va='center')
fig.text(0.05, 0.5, 'Validation Loss          Training Loss', ha='center', va='center', rotation='vertical')
plt.show()

# %% [markdown]
# ### Step 09. Predictions

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Future", "Model Prediction"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return


for x, y in dataset_val.take(5):
    show_plot([x[0][:, 1].numpy(), y[0].numpy(), model.predict(x)[0]],12,"Single Step Prediction",)
for x, y in dataset_val.take(5):
    show_plot([x[0][:, 1].numpy(), y[0].numpy(), model_gru.predict(x)[0]],12,"Single Step Prediction by GRU Model",)
for x, y in dataset_val.take(5):
    show_plot([x[0][:, 1].numpy(), y[0].numpy(), model_gru_drop.predict(x)[0]],12,"Single Step Prediction by GRU w| dropout=0.2",)
